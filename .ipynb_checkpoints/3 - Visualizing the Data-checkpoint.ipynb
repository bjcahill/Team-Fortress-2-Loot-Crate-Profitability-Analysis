# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from altair import *
pd.options.display.max_rows = 10

# %%
unusuals_df = pd.read_csv("CompleteHatAndPricingData.csv")
unusuals_df = unusuals_df[unusuals_df.columns.drop("Unnamed: 0")]
unusuals_df
# Out:
#              Name                  Effect  Price  Class Item Type  \
# 0      Dread Knot          Burning Flames   30.0  Heavy  Cosmetic
# 1      Dread Knot          Circling Heart    NaN  Heavy  Cosmetic
# 2      Dread Knot     Circling Peace Sign   10.0  Heavy  Cosmetic
# 3      Dread Knot        Circling TF Logo    9.0  Heavy  Cosmetic
# 4      Dread Knot          Green Confetti    9.0  Heavy  Cosmetic
# ...           ...                     ...    ...    ...       ...
# 41276  Snowcapped  Magnetic Hat Protector    NaN  Medic  Cosmetic
# 41277  Snowcapped   Voltaic Hat Protector    NaN  Medic  Cosmetic
# 41278  Snowcapped          Galactic Codex    NaN  Medic  Cosmetic
# 41279  Snowcapped           Ancient Codex    NaN  Medic  Cosmetic
# 41280  Snowcapped                  Nebula    NaN  Medic  Cosmetic
#
#       Equip Region      Grade          Unboxed From   Robo Generation  \
# 0          Regular   No Grade            Old Series  False  First Gen
# 1          Regular   No Grade            Old Series  False  First Gen
# 2          Regular   No Grade            Old Series  False  First Gen
# 3          Regular   No Grade            Old Series  False  First Gen
# 4          Regular   No Grade            Old Series  False  First Gen
# ...            ...        ...                   ...    ...        ...
# 41276      Regular  Mercenary  Winter 2018 Cosmetic  False   Invasion
# 41277      Regular  Mercenary  Winter 2018 Cosmetic  False   Invasion
# 41278      Regular  Mercenary  Winter 2018 Cosmetic  False   Invasion
# 41279      Regular  Mercenary  Winter 2018 Cosmetic  False   Invasion
# 41280      Regular  Mercenary  Winter 2018 Cosmetic  False   Invasion
#
#        Effect Community Rating  Crate Cosmetic  \
# 0                      4.59375            True
# 1                      3.06250            True
# 2                      2.21875            True
# 3                      2.34375            True
# 4                      1.40625            True
# ...                        ...             ...
# 41276                  2.15625           False
# 41277                  2.09375           False
# 41278                  1.43750           False
# 41279                  1.46875           False
# 41280                  4.87500           False
#
#        Months Since Last Price Update  Effect Median Price  Hat Median Price  \
# 0                                   9               104.00              14.0
# 1                                  -1                36.25              14.0
# 2                                  21                22.00              14.0
# 3                                  44                21.50              14.0
# 4                                  15                17.00              14.0
# ...                               ...                  ...               ...
# 41276                              -1                20.50              22.0
# 41277                              -1                52.50              22.0
# 41278                              -1                36.75              22.0
# 41279                              -1                19.50              22.0
# 41280                              -1               180.00              22.0
#
#        Hat Rating  Effect Rating  Median Effect Rating  Median Hat Rating
# 0           -7.40            1.6                6.7375            -1.6000
# 1             NaN            NaN                0.4500            -1.6000
# 2           -1.20           -0.4               -0.8500            -1.6000
# 3           -1.25           -0.5               -0.9125            -1.6000
# 4           -0.80           -0.5               -1.3750            -1.6000
# ...           ...            ...                   ...                ...
# 41276         NaN            NaN               -0.9000            -0.1625
# 41277         NaN            NaN               -1.1750            -0.1625
# 41278         NaN            NaN               -1.1000            -0.1625
# 41279         NaN            NaN               -1.2500            -0.1625
# 41280         NaN            NaN               14.5000            -0.1625
#
# [41281 rows x 19 columns]

# %%
from altair import *

domain = ["Scout","Soldier","Pyro","Demoman","Heavy","Engineer","Medic","Sniper","All classes","Multi-Class"]
range_ = ['#194FAE', '#194FAE', '#194FAE','#194FAE','#194FAE','#194FAE','#194FAE','#194FAE','#EE8130','#FFCE00']

data_transformers.enable('json')
Chart(unusuals_df).mark_circle(size = 60).encode(
    x=X("Effect Community Rating"),
    y=Y("Price", scale=Scale(type='log',base = 2)),
    color=Color('Class', scale=Scale(domain = domain,range = range_)),
    column="Item Type"
).configure_mark(
    opacity=0.6)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
cosmetics_df = unusuals_df[unusuals_df["Item Type"] == "Cosmetic"]

# %%
# %%capture --no-stdout
cosmetics_df ["Type of Cosmetic Unusual"] = cosmetics_df.apply(
    lambda row: "Category 1: Robo" if row["Robo"] == True else "Category 2: Regular",
    axis=1)
cosmetics_df ["Type of Cosmetic Unusual"] = cosmetics_df.apply(
    lambda row: "Category 3: Misc" if row["Equip Region"] == "Misc" and row["Type of Cosmetic Unusual"] == "Category 2: Regular" else row["Type of Cosmetic Unusual"],
    axis=1)

# %%
domain = ["Mercenary","No Grade","Commando","Assassin","Elite"]
range_ = ['#194FAE','#56AC4D','#582685', '#FF00A7','#FF0000']

data_transformers.enable('json')
Chart(cosmetics_df).mark_circle().encode(
    x=X("Effect Community Rating"),
    y=Y("Price", scale=Scale(type='log',base = 2)),
    color=Color('Grade', scale=Scale(domain = domain,range = range_)),
    column="Type of Cosmetic Unusual",
    size = Size("Grade",scale=Scale(domain = ["Mercenary","No Grade","Commando","Assassin","Elite"], range = [50,200,400,8000,10000]))
).configure_mark(
    opacity=0.6)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
unusuals_df["Type of Crate"] = unusuals_df["Type of Crate Temp"]

unusuals_df["Type of Crate Temp"] = unusuals_df["Unboxed From"].str.contains("Crate")
unusuals_df["Type of Crate"] = unusuals_df.apply(
    lambda row: "Category 1: Unlocked Crate" if row["Type of Crate Temp"] == True else "Category 2: Other Series",
    axis=1)

unusuals_df["Type of Crate"].value_counts()
# Out:
# Category 2: Other Series      22172
# Category 1: Unlocked Crate    19109
# Name: Type of Crate, dtype: int64

# %%
median_prices = unusuals_df.groupby("Name")["Price"].median().to_frame().reset_index().rename(columns = {"Price": "Median Hat Price"})
unique_hats_df = unusuals_df.merge(median_prices,on = "Name",how = "left").drop_duplicates("Name")

# %%
Chart(unique_hats_df[unique_hats_df["Median Hat Rating"] < 25]).mark_circle(size = 60).encode(
    x=X("Median Hat Rating"),
    y=Y("Median Hat Price", scale=Scale(type='log',base = 2)),
    color=Color('Grade', scale=Scale(domain = domain,range = range_)),
    column="Type of Crate",
    size = Size("Grade",scale=Scale(domain = ["Mercenary","No Grade","Commando","Assassin","Elite"], range = [50,200,400,8000,10000]))
).configure_mark(
    opacity=0.5)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
unusuals_df.groupby("Unboxed From")["Price","Class"].median().sort_values(by = "Price",ascending = False)[1:]["Price"].plot.bar(figsize = (15,6))

# %%
Chart(unusuals_df.groupby("Effect Community Rating")["Price"].mean().to_frame().reset_index()).mark_area(
    color="lightblue",
    interpolate='step-after',
    line=True
).encode(
    x='Effect Community Rating',
    y=Y("Price", scale=Scale(type='log',base = 2))
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# Clearly it appears that multi class or all class hats sell for more
